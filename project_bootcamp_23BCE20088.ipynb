# %%
import pandas as pd
import numpy as np
pd.DataFrame(pd.read_excel(r'C:\Users\Dell\python Class\project.xlsx'))

# %%
df
# Out:
#     pollution_2023  pollution_growth_Rate   country_name  ccn3 country_region  \
# 0       1428627663                0.00808          India   356           Asia
# 1       1425671352               -0.00015          China   156           Asia
# 2        339996563                0.00505  United States   840  North America
# 3        277534122                0.00738      Indonesia   360           Asia
# 4        240485658                0.01976       Pakistan   586           Asia
# 5        223804632                0.02408        Nigeria   566         Africa
# 6        216422446                0.00515         Brazil    76  South America
# 7        172954319                0.01033     Bangladesh    50           Asia
# 8        144444359               -0.00186         Russia   643         Europe
# 9        128455567                0.00746         Mexico   484  North America
# 10       126527060                0.02551       Ethiopia   231         Africa
# ...

# %%
df[['country_name','country_region','pollution_2023']]

# %%
df.drop('share_borders',axis=1,inplace=True)

# %%
df

# %%
df.drop(df.index[16:],axis=0,inplace=True)

# %%
df
# Out:
#     pollution_2023  pollution_growth_Rate   country_name  ccn3 country_region  \
# 0       1428627663                0.00808          India   356           Asia
# 1       1425671352               -0.00015          China   156           Asia
# 2        339996563                0.00505  United States   840  North America
# 3        277534122                0.00738      Indonesia   360           Asia
# 4        240485658                0.01976       Pakistan   586           Asia
# 5        223804632                0.02408        Nigeria   566         Africa
# 6        216422446                0.00515         Brazil    76  South America
# 7        172954319                0.01033     Bangladesh    50           Asia
# 8        144444359               -0.00186         Russia   643         Europe
# 9        128455567                0.00746         Mexico   484  North America
# 10       126527060                0.02551       Ethiopia   231         Africa
# ...

# %%
df.loc[0]

# %%
df.loc[0,"pollution_2023"]

# %%
df.loc[df.index[:10],["country_name","pollution_Rank"]]
# Out:
#     country_name  pollution_Rank
# 0          India               1
# 1          China               2
# 2  United States               3
# 3      Indonesia               4
# 4       Pakistan               5
# 5        Nigeria               6
# 6         Brazil               7
# 7     Bangladesh               8
# 8         Russia               9
# 9         Mexico              10

# %%
df[df["pollution_density_per_Mile"]>500]
# Out:
#     pollution_2023  pollution_growth_Rate country_name  ccn3 country_region  \
# 0       1428627663                0.00808        India   356           Asia
# 4        240485658                0.01976     Pakistan   586           Asia
# 5        223804632                0.02408      Nigeria   566         Africa
# 7        172954319                0.01033   Bangladesh    50           Asia
# 11       123294513               -0.00530        Japan   392           Asia
# 12       117337368                0.01539  Philippines   608           Asia
# 15        98858950                0.00685      Vietnam   704           Asia
#
#     united_nation_Member  country_land_Area_in_Km  pollution_density_in_km  \
# 0                   True                2973190.0                 480.5033
# 4                   True                 770880.0                 311.9625
# 5                   True                 910770.0                 245.7312
# ...

# %%
import matplotlib.pyplot as plt
x = df['pollution_Rank']
y = df["pollution_2023"]
z = df["pollution_density_per_Mile"]
plt.plot(x,y,'g-*')
plt.plot(x,z,"b--")
plt.xlabel("Pollution Rank")
plt.ylabel("Pollution")
# Out:
# Text(0, 0.5, 'Pollution')
